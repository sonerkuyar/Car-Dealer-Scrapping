# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import pandas as pd

# %%
website = "https://www.arabam.com/ikinci-el/otomobil?take=50&view=Detailed"

# %%
headers = {"User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36"}

response = requests.get(website, headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content,'html.parser')

# %%
len(results)
# Out:
# 16

# %%
results = soup.find_all("div", {"class":"content-container"})

# %%
len(results)
# Out:
# 51

# %% [markdown]
# # Id

# %%
results[50]
# Out:
# <div class="content-container">
# <a href="{{advertUrl}}?utm_source=recommendation&amp;utm_medium=click&amp;utm_campaign=listeleme" onclick="window.dataLayer.push({Category:'Recommendation', Action:'Listing', Label:'Click_listing', event: 'gaEvent'})" target="_self">
# <div class="df df-jcsbetween">
# <p class="bold">{{advertCity}}</p>
# <p class="model-year semi-bold">{{advertYear}}</p>
# </div>
# <div class="model-name">{{advertTitle}}</div>
# <div class="price-and-icon-wrapper tar">
# <div class="price">{{advertFormmatedPrice}}</div>
# </div>
# </a>
# </div>

# %%
for i in range(50):
    print(results[i].find('p',{"class":"id"}).get_text().strip())
# Out:
# İlan No: 21019561
# İlan No: 21132048
# İlan No: 21093071
# İlan No: 21131104
# İlan No: 21131195
# İlan No: 21131146
# İlan No: 20304267
# İlan No: 21116671
# İlan No: 21130508
# İlan No: 21130515
# İlan No: 21129994
# İlan No: 21128110
# İlan No: 21130266
# İlan No: 20886966
# İlan No: 21130169
# İlan No: 21130146
# İlan No: 21130078
# İlan No: 21061304
# İlan No: 21130032
# İlan No: 21129929
# İlan No: 21093853
# İlan No: 21062374
# İlan No: 20647512
# İlan No: 21129831
# İlan No: 21129780
# İlan No: 21089577
# İlan No: 21129608
# İlan No: 21096551
# İlan No: 21129712
# İlan No: 21105690
# İlan No: 21112498
# İlan No: 21112445
# İlan No: 21112435
# İlan No: 21129271
# İlan No: 21129210
# İlan No: 21129214
# İlan No: 21129205
# İlan No: 21129192
# İlan No: 21129167
# İlan No: 21126635
# İlan No: 21110362
# İlan No: 21118350
# İlan No: 21107061
# İlan No: 21119559
# İlan No: 21118399
# İlan No: 21128334
# İlan No: 20709930
# İlan No: 20679689
# İlan No: 20584087
# İlan No: 21092282

# %%
id_list = list()
for elem in results[:-1:]:
    id = elem.find('p',{"class":"id"}).get_text().strip().split()[2]
    id_list.append(id)

# %% [markdown]
# # cars at pages

# %%
PAGE_NUMBER = 50
id_list = list()

for i in range(PAGE_NUMBER):
    webiste = f"https://www.arabam.com/ikinci-el/otomobil?take=50&view=Detailed&page={i+1}"
    response = requests.get(website, headers=headers)
    soup = BeautifulSoup(response.content,'html.parser')
    '''results = soup.find_all("div", {"class":"content-container"})
    for elem in results[:-1:]:
        id = elem.find('p',{"class":"id"}).get_text().strip().split()[2]
        id_list.append(id)
    '''

# %%
len(id_list)
# Out:
# 2500

# %% [markdown]
# # car specific features

# %%
website = "https://www.arabam.com/ilan/20310549"
response = requests.get(website, headers=headers)
soup = BeautifulSoup(response.content,'html.parser')

# %%
results = soup.find_all("li",{"class":"bcd-list-item"})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [172], in <cell line: 2>()
#       1 results = soup.find_all("li",{"class":"bcd-list-item"})
# ----> 2 results.isempty()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/bs4/element.py:2289, in ResultSet.__getattr__(self, key)
#    2287 def __getattr__(self, key):
#    2288     """Raise a helpful exception to explain a common code fix."""
# -> 2289     raise AttributeError(
#    2290         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2291     )
#
# AttributeError: ResultSet object has no attribute 'isempty'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
results[-1].get_text().strip().split()
car_dict = dict()
for elem in results:  
    features_car = ''.join(elem.get_text().split()).split(":")
    car_dict.update({features_car[0]:features_car[1]})
pd.DataFrame([car_dict])
    
    
        
    
    #print(elem.get_text().replace(" ","").strip())
# Out:
#      İlanNo     İlanTarihi  Marka     Seri        Model   Yıl  Kilometre  \
# 0  20310569  11Ağustos2022  Skoda  Octavia  1.4TSISport  2018  115.000km
#
#       VitesTipi YakıtTipi     KasaTipi MotorHacmi MotorGücü       Çekiş  \
# 0  YarıOtomatik    Benzin  Hatchback/5     1395cc     150hp  ÖndenÇekiş
#
#   Ort.YakıtTüketimi YakıtDeposu   Boya-değişen       TakasaUygun      Kimden
# 0               5lt        50lt  Tamamıorjinal  TakasaUygunDeğil  Sahibinden

# %%
import time
import lxml
start_time = time.time()
session_object = requests.Session()
headers = {"User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36"}
all_car_df = pd.DataFrame()
all_id = id_list
for car_id in all_id:
    website = f"https://www.arabam.com/ilan/{car_id}"
    response = session_object.get(website, headers=headers)
    soup = BeautifulSoup(response.text,'lxml')
    results = soup.find_all("li",{"class":"bcd-list-item"})
    if len(results) ==0:
        continue
    results[-1].get_text().strip().split()
    car_dict = dict()
    for elem in results:  
        features_car = ''.join(elem.get_text().split()).split(":")
        car_dict.update({features_car[0]:features_car[1]})
    car_df = pd.DataFrame([car_dict])
    all_car_df = pd.concat([car_df,all_car_df])

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 19.42912721633911 seconds ---

# %%
all_car_df.reset_index(inplace=True)

# %%
all_car_df
# Out:
#     index    İlanNo  İlanTarihi          Marka     Seri  \
# 0       0  21092282  07Ekim2022     Volkswagen   Passat
# 1       0  20584087  07Ekim2022        Renault     Clio
# 2       0  20679689  07Ekim2022        Renault   Symbol
# 3       0  20709930  07Ekim2022           Opel   Vectra
# 4       0  21128334  07Ekim2022           Ford   Fiesta
# 5       0  21118399  08Ekim2022           Ford    B-Max
# 6       0  21119559  08Ekim2022     Volkswagen     Golf
# 7       0  21107061  08Ekim2022        Citroen       C3
# 8       0  21118350  08Ekim2022           Ford    Focus
# 9       0  21110362  08Ekim2022           Fiat    Linea
# 10      0  21126635  08Ekim2022          Skoda    Fabia
# 11      0  21129167  08Ekim2022          Tofaş    Şahin
# 12      0  21129192  08Ekim2022           Fiat     Egea
# 13      0  21129205  08Ekim2022           Fiat     Egea
# 14      0  21129214  08Ekim2022           Fiat     Egea
# 15      0  21129210  08Ekim2022        Peugeot      301
# 16      0  21129271  08Ekim2022        Hyundai      i20
# 17      0  21112435  08Ekim2022          Honda    Civic
t     Belirtilmemiş  TakasaUygunDeğil   Galeriden
# 5          NaN     Belirtilmemiş       TakasaUygun   Galeriden
# 6          NaN     Belirtilmemiş       TakasaUygun   Galeriden
# 7          NaN     Belirtilmemiş       TakasaUygun   Galeriden
# 8          NaN     Belirtilmemiş       TakasaUygun   Galeriden
# 9         45lt     Belirtilmemiş       TakasaUygun   Galeriden
# 10        45lt  1değişen,2boyalı  TakasaUygunDeğil  Sahibinden
# 11        52lt     Belirtilmemiş  TakasaUygunDeğil   Galeriden
# 12        45lt     Belirtilmemiş  TakasaUygunDeğil   Galeriden
# 13        45lt     Belirtilmemiş  TakasaUygunDeğil   Galeriden
# 14        45lt     Belirtilmemiş  TakasaUygunDeğil   Galeriden
# 15        50lt     Tamamıorjinal  TakasaUygunDeğil   Galeriden
# 16        45lt     Tamamıorjinal  TakasaUygunDeğil   Galeriden
# 17        47lt     Belirtilmemiş  TakasaUygunDeğil   Galeriden
# 18        49lt     Belirtilmemiş  TakasaUygunDeğil   Galeriden
# 19        50lt     Belirtilmemiş  TakasaUygunDeğil   Galeriden
# 20        60lt     Belirtilmemiş       TakasaUygun   Galeriden
# 21        60lt     Tamamıorjinal       TakasaUygun   Galeriden
# 22        45lt  3değişen,6boyalı       TakasaUygun   Galeriden
# 23        65lt  1değişen,1boyalı       TakasaUygun   Galeriden
# 24        50lt  1değişen,6boyalı  TakasaUygunDeğil  Sahibinden
# 25        52lt     Belirtilmemiş       TakasaUygun   Galeriden
# 26        53lt     Belirtilmemiş       TakasaUygun   Galeriden
# 27        50lt     Tamamıorjinal       TakasaUygun   Galeriden
# 28        45lt  2değişen,2boyalı       TakasaUygun   Galeriden
# 29        50lt     Belirtilmemiş       TakasaUygun   Galeriden
# 30        47lt     Belirtilmemiş       TakasaUygun   Galeriden
# 31        50lt     Tamamıorjinal       TakasaUygun   Galeriden
# 32        45lt     Tamamıorjinal  TakasaUygunDeğil   Galeriden
# 33        70lt     Tamamıorjinal       TakasaUygun   Galeriden
# 34        45lt     Tamamıorjinal       TakasaUygun   Galeriden
# 35        45lt     Belirtilmemiş       TakasaUygun   Galeriden
# 36        45lt           4boyalı       TakasaUygun  Sahibinden
# 37        42lt     Tamamıorjinal       TakasaUygun   Galeriden
# 38        50lt     Belirtilmemiş  TakasaUygunDeğil  Sahibinden
# 39        55lt     Belirtilmemiş  TakasaUygunDeğil  Sahibinden
# 40        60lt     Tamamıorjinal       TakasaUygun   Galeriden
# 41        60lt     Belirtilmemiş       TakasaUygun   Galeriden
# 42         NaN     Tamamıorjinal  TakasaUygunDeğil   Galeriden
# 43        42lt           3boyalı       TakasaUygun   Galeriden
# 44        60lt     Belirtilmemiş  TakasaUygunDeğil   Galeriden
# 45        66lt     Belirtilmemiş       TakasaUygun   Galeriden
# 46        45lt     Belirtilmemiş       TakasaUygun   Galeriden
# 47        43lt     Belirtilmemiş  TakasaUygunDeğil   Galeriden
# 48        50lt     Tamamıorjinal  TakasaUygunDeğil   Galeriden
# 49        52lt  2değişen,3boyalı       TakasaUygun  Sahibinden
